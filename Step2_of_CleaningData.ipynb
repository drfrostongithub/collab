# %% [markdown]
# <a href="https://colab.research.google.com/github/drfrostongithub/collab/blob/main/Step2_of_CleaningData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the data
df = pd.read_csv('/content/FormatManualKuesioner.csv')

# Function to extract the number
def extract_number(text):
    if isinstance(text, str):
        return text.split(' ')[0]
    return text

# Apply the function to all columns
for col in df.columns:
  df[col] = df[col].apply(extract_number)

# Display the first few rows to check the result
display(df.head())
# Out:
#   PE1 PE2 PE3 PE4 EE1 EE2 EE3 EE4 SI1 SI2  ... E2 E3 BI1 BI2 BI3 BI4 BI5  \
# 0   5   5   4   4   5   4   4   4   5   4  ...  5  5   5   5   5   5   5
# 1   5   4   6   4   6   6   6   5   2   3  ...  6  4   6   6   6   4   5
# 2   6   5   6   5   5   5   2   5   4   4  ...  4  4   4   4   4   4   4
# 3   4   4   4   4   4   4   4   4   4   4  ...  3  4   4   5   3   4   5
# 4   5   4   4   4   4   4   4   3   4   5  ...  5  4   3   4   4   4   4
#
#   BAGC1 BAGC2 BAGC3
# 0     4     5     4
# 1     5     6     3
# 2     2     2     2
# 3     4     4     4
# 4     3     3     4
#
# [5 rows x 28 columns]

# %%
# Save the dataframe to a CSV file
df.to_csv('processed_data.csv', index=False)

# %% [markdown]
# The dataframe has been saved to `processed_data.csv`. You can now download this file from the file explorer in the left sidebar.
